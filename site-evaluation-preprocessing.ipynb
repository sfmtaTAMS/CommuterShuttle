# %%
import pandas as pd
from tabulate import tabulate

# %%
# Save cleaned data in CSVData folder
# Change this to name of the current spreadsheet you are working with by copying relative path
csv_file = "CSVData\Commuter Shuttle Evaluation Data Export 2024-08-01.csv"
df = pd.read_csv(csv_file)

# %%
# Displays head of the table
print(tabulate(df.head(), headers='keys', tablefmt='pretty'))
# Out:
# +---+--------+-----------------+-----------------+----------------------------+------------------+---------------+-----------------+-----------------------------------------+---------------------------------------------+--------------------------------------------------------------------------------+------------------------------------------------------+--------------------------------------------------------------+-------------------------------+----------------------------------+------------------------------------------------------------------------+---------------------------------------------------------+---------------------------------------------+-----------------------------------------------------+-------------------------------------------------------------+-----------------------------------------+-----------------------------------------------------------------+--------------------------------------------------------------+-----------------------------------------+-------------------------------------------+-----------------------------------------------+--------------------------------------+-----------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------+--------+--------------------+
# |   | Id_NEW |   Start time    | Completion time |           Email            |       Name       |   Your Name   | Shuttle Stop ID |          Shuttle Stop Location          | What type of commuter shuttle stop is this? | What are the listed hours for Permitted Commuter Shuttle Loading at this stop? | Are you evaluating this stop in person or virtually? | Month & Year of snapshot from Google Streetview (or similar) | Date of In-Person Observation | Start Time of Observation Period | Are you observing during active use of the stop by a commuter shuttle? | Does the shuttle have enough space to park/load/unload? | Why does the shuttle not have enough space? | What are potential issues with extending this zone? | Is the shuttle free from obstructions while using the stop? | In what ways is the shuttle obstructed? | Does the site have posted signage for commuter shuttle permits? | Does posted signage include hours for commuter shuttle use?  | Does the signage seem to be up-to-date? | How might the signage need to be updated? | Does the curb paint match the posted signage? | Is the curb paint in good condition? |              What are potential issues with the quality of the curb paint?              |                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Photos                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |                                                  Other Site Notes                                                   | ID_OLD | Last modified time |
# +---+--------+-----------------+-----------------+----------------------------+------------------+---------------+-----------------+-----------------------------------------+---------------------------------------------+--------------------------------------------------------------------------------+------------------------------------------------------+--------------------------------------------------------------+-------------------------------+----------------------------------+------------------------------------------------------------------------+---------------------------------------------------------+---------------------------------------------+-----------------------------------------------------+-------------------------------------------------------------+-----------------------------------------+-----------------------------------------------------------------+--------------------------------------------------------------+-----------------------------------------+-------------------------------------------+-----------------------------------------------+--------------------------------------+-----------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------+--------+--------------------+
# | 0 |   1    | 7/16/2024 17:00 | 7/16/2024 17:20 |         anonymous          |       nan        |    Matthew    |     13401.0     |            19th Ave & Wawona            |           Dedicated Shuttle Stop            |                              4PM to 10PM Mon-Fri;                              |                       Virtual                        |                            Apr-24                            |              nan              |               nan                |                                  nan                                   |                           nan                           |                     nan                     |                         nan                         |                             nan                             |                   nan                   |                               Yes                               |                             Yes                              |                   Yes                   |                    nan                    |                     Maybe                     |                Maybe                 | it's hard to tell how faded the white paint is, and if you can see SFMTA markings, etc. |                   https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos/Screenshot%202024-07-16%20171933_anonymous.png; https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos/Screenshot%202024-07-16%20171927_anonymous.png; https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos/Screenshot%202024-07-16%20171919_anonymous.png; https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos
://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos/Screenshot%202024-07-17%20130052_Alexandra%20Ray.png                                                                                                                                                                                                                                           |                                                         nan                                                         |  nan   |        nan         |
# | 4 |   5    | 7/17/2024 13:02 | 7/17/2024 13:10 |  Alexandra.Ray@sfmta.com   |  Alexandra Ray   | Alexandra Ray |     20047.0     |     Gough St & Geary Blvd SW corner     |           Dedicated Shuttle Stop            |                      6:00AM to 10:00AM, Monday to Friday                       |                       Virtual                        |                            Jan-23                            |              nan              |               nan                |                                  nan                                   |                           nan                           |                     nan                     |                         nan                         |                             nan                             |                   nan                   |                               Yes                               |                             Yes                              |                   Yes                   |                    nan                    |                     Maybe                     |                 Yes                  |                                           nan                                           |                                                                                                                                                                                                                                           https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos/Screenshot%202024-07-17%20130738_Alexandra%20Ray.png; https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos/Screenshot%202024-07-17%20130810_Alexandra%20Ray.png                                                                                                                                                                                                                                           |                                                         nan                                                         |  nan   |        nan         |
# +---+--------+-----------------+-----------------+----------------------------+------------------+---------------+-----------------+-----------------------------------------+---------------------------------------------+--------------------------------------------------------------------------------+------------------------------------------------------+--------------------------------------------------------------+-------------------------------+----------------------------------+------------------------------------------------------------------------+---------------------------------------------------------+---------------------------------------------+-----------------------------------------------------+-------------------------------------------------------------+-----------------------------------------+-----------------------------------------------------------------+--------------------------------------------------------------+-----------------------------------------+-------------------------------------------+-----------------------------------------------+--------------------------------------+-----------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------+--------+--------------------+

# %%
# Renaming column names

# Display the current column names
# print("Current column names:")
# print(df.columns)

# Create a dictionary to rename columns
rename_dict = {
    'Id_NEW': 'ID',
    'Start time': 'Start_Time',
    'Completion time': 'Completion_Time',
    'Email': 'Email_Address',
    'Name': 'Name',
    'Your Name': 'Evaluator_Name',
    'Shuttle Stop ID': 'Shuttle_Stop_ID',
    'Shuttle Stop Location': 'Shuttle_Stop_Location',
    'What type of commuter shuttle stop is this?': 'Shuttle_Stop_Type',
    'What are the listed hours for Permitted Commuter Shuttle Loading at this stop?': 'Listed_Hours',
    'Are you evaluating this stop in person or virtually?': 'Evaluation_Type',
    'Month & Year of snapshot from Google Streetview (or similar)': 'Streetview_Snapshot',
    'Date of In-Person Observation': 'In_Person_Observation_Date',
    'Start Time of Observation Period': 'Observation_Start_Time',
    'Are you observing during active use of the stop by a commuter shuttle?': 'Active_Use_Observation',
    'Does the shuttle have enough space to park/load/unload?': 'Shuttle_Parking_Space',
    'Why does the shuttle not have enough space?': 'No_Space_Reason',
    'What are potential issues with extending this zone?': 'Zone_Extension_Issues',
    'Is the shuttle free from obstructions while using the stop?': 'Shuttle_Lack_Obstructions',
    'In what ways is the shuttle obstructed?': 'Obstruction_Details',
    'Does the site have posted signage for commuter shuttle permits?': 'Signage_Present',
    'Does posted signage include hours for commuter shuttle use?': 'Signage_Hours',
    'Does the signage seem to be up-to-date?': 'Signage_Updated',
    'How might the signage need to be updated?': 'Signage_Update_Needed',
    'Does the curb paint match the posted signage?': 'Curb_Paint_Match_Signage',
    'Is the curb paint in good condition?': 'Curb_Paint_Condition',
    'What are potential issues with the quality of the curb paint?': 'Curb_Paint_Quality_Issues',
    'Photos': 'Photos',
    'Other Site Notes': 'Other_Site_Notes',
    'ID_OLD': 'Old_ID',
    'Last modified time': 'Last_Modified_Time',
    'Unnamed: 31': 'Additional_Info'
}

# Rename the columns
df.rename(columns=rename_dict, inplace=True)

# New column names
# print("Current column names:")
# print(df.columns)

# %%
# Find duplicates based on 'Shuttle_Stop_ID'
duplicate_rows = df[df.duplicated(subset='Shuttle_Stop_ID', keep=False)]

# Extract unique IDs with duplicates
duplicate_ids = duplicate_rows['Shuttle_Stop_ID'].nunique()

# Original number of evaluations
row_count_original = len(df)
print(f"Original number of rows: {row_count_original}")

# Number of unique entires 
total_unique_entries = df['Shuttle_Stop_ID'].nunique()
print(f"Number of unique rows: {total_unique_entries}")

# Number of duplicate entries
total_duplicate_entries = len(duplicate_rows)
print(f"Number of duplicate rows: {total_duplicate_entries}")

# Number of unique duplicate entries
total_unique_duplicate_entries = duplicate_rows['Shuttle_Stop_ID'].nunique()
print(f"Number of unique duplicate rows: {total_unique_duplicate_entries}")

# Reorder columns to have 'Shuttle_Stop_ID' first
columns_order = ['Shuttle_Stop_ID', 'Evaluation_Type'] + [col for col in duplicate_rows.columns if col != 'Shuttle_Stop_ID' and col != 'Evalution_Type']
duplicate_rows = duplicate_rows[columns_order]

# Display the duplicates
duplicate_rows_sorted = duplicate_rows.sort_values(by='Shuttle_Stop_ID')
print("Duplicate ID rows:", duplicate_ids)
# print(tabulate(duplicate_rows_sorted, headers='keys', tablefmt='pretty'))
# Out:
# Original number of rows: 93
# Number of unique rows: 79
# Number of duplicate rows: 21
# Number of unique duplicate rows: 8
# Duplicate ID rows: 8

# %%
# Count the occurrences of each unique value in 'Signage_Updated'
signage_counts = df['Signage_Updated'].value_counts()

# Convert the counts to a DataFrame for better formatting
signage_counts_df = signage_counts.reset_index()
signage_counts_df.columns = ['Signage_Updated', 'Count']

# Print the tabulated counts
print("Number of unique responses for signage update:")
print(tabulate(signage_counts_df, headers='keys', tablefmt='pretty'))
# Out:
# Number of unique responses for signage update:
# +---+--------------------------------------------+-------+
# |   |              Signage_Updated               | Count |
# +---+--------------------------------------------+-------+
# | 0 |                    Yes                     |  40   |
# | 1 |                   Maybe                    |  10   |
# | 2 |                     No                     |   3   |
# | 3 | Very faded, barely legible, needs new sign |   1   |
# +---+--------------------------------------------+-------+

# %%
df['Completion_Time'] = pd.to_datetime(df['Completion_Time'], errors='coerce')

# Sort by 'Shuttle Stop ID' and 'Completion time' (most recent last)
df = df.sort_values(by=['Shuttle_Stop_ID', 'Completion_Time'])

# Drop duplicates, keeping the most recent entry
df = df.drop_duplicates(subset='Shuttle_Stop_ID', keep='last')

# Reorder columns to have 'Shuttle Stop ID' first
columns_order = ['Shuttle_Stop_ID'] + [col for col in df.columns if col != 'Shuttle Stop ID' and col != 'Completion_Time']
df = df[columns_order]

print(f"Number of unique rows: {total_unique_entries}")
total_current_rows = len(df['Shuttle_Stop_ID'].nunique())
print(f"Number of current rows: {total_current_rows}")

print(tabulate(df, headers='keys', tablefmt='pretty'))
# Out:
# Number of unique rows: 79
# Number of current rows: 2
# +----+-----------------+----+-----------------+----------------------------+------------------+------------------+-----------------+-------------------------------------------------------------------------------+------------------------------+------------------------------------------------------------------------+-----------------+---------------------+----------------------------+------------------------+------------------------+-----------------------+--------------------------------------------------+------------------------------------------------------------------------+---------------------------+---------------------------------------------------------------------------------------------------------+------------------------------------------------------------+--------------------------------------------------------------+--------------------------------------------+---------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+--------------------+
# |    | Shuttle_Stop_ID | ID |   Start_Time    |       Email_Address        |       Name       |  Evaluator_Name  | Shuttle_Stop_ID |                             Shuttle_Stop_Location                             |      Shuttle_Stop_Type       |                              Listed_Hours                              | Evaluation_Type | Streetview_Snapshot | In_Person_Observation_Date | Observation_Start_Time | Active_Use_Observation | Shuttle_Parking_Space |                 No_Space_Reason                  |                         Zone_Extension_Issues                          | Shuttle_Lack_Obstructions |                                           Obstruction_Details                                           |                      Signage_Present                       | Does posted signage include hours for commuter shuttle use?  |              Signage_Updated               |                              Signage_Update_Needed                              |                                                                   Curb_Paint_Match_Signage                                                                    |                         Curb_Paint_Condition                         |                                              Curb_Paint_Quality_Issues                                               |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Photos                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |                                                                                                                       Other_Site_Notes                                                                                                                       | Old_ID | Last_Modified_Time |
# +----+-----------------+----+-----------------+----------------------------+------------------+------------------+-----------------+-------------------------------------------------------------------------------+------------------------------+------------------------------------------------------------------------+-----------------+---------------------+----------------------------+------------------------+------------------------+-----------------------+--------------------------------------------------+------------------------------------------------------------------------+---------------------------+---------------------------------------------------------------------------------------------------------+------------------------------------------------------------+--------------------------------------------------------------+--------------------------------------------+---------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+--------------------+
# | 24 |     13209.0     | 25 | 7/25/2024 16:14 | Matthew.Thompson@sfmta.com | Matthew Thompson | Matthew Thompson |     13209.0     |                  8th St & Market St SW corner, far-side stop                  |       Muni Shared Stop       |                                  None                                  |    In Person    |         nan         |         7/25/2024          |       4:10:00 PM       |           No           |          nan          |                       nan                        |                                  nan                                   |            nan            |                                                   nan                                                   |                             No                             |                             nan                              |                    nan                     |                                       nan                                       |                                                                              nan                                                                              |                                Maybe                                 |                     Paint is generally good condition…there is some faded stenciling & graffiti                      |                                                                                                                                                                                                                                                                                                                         https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos/IMG_5815_Matthew%20Thompson.jpeg; https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos/IMG_5816_Matthew%20Thompson.jpeg; https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos/IMG_5817_Matthew%20Thompson.jpeg; https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos/IMG_5818_Matthew%20Thompson.jpeg; https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos/IMG_5819_Matthew%20Thompson.jpeg; https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos/IMG_5820_Matthew%20Thompson.jpeg; https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos/IMG_5821_Matthew%20Thompson.jpeg                                                                                                                                                                                                                                                                                                                         |                                                                                                                             nan                                                                                                                              |  nan   |        nan         |
# | 40 |     13292.0     | 41 | 7/29/2024 17:40 | Matthew.Thompson@sfmta.com | Matthew Thompson | Matthew Thompson |     13292.0     |                   16th St&Mission SE corner, far-side stop                    |       Muni Shared Stop       |                                  None                                  |    In Person    |         nan         |         7/29/2024          |       5:36:00 PM       |           No           |          nan          |                       nan                        |                                  nan                                   |            nan            |                                                   nan                                                   |                             No                             |                             nan                              |                    nan                     |                                       nan                                       |                                                                              nan                                                                              |                                Maybe                                 |                  Red paint is visible but getting chipped, and stenciling is generally not visible                   |                                                                                                                                                                                                                                                                                                                         https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                                                                          Clearly a loading zone, just no mention of commuter shuttle except white paint saying "passenger loading"                                                                           |  nan   |        nan         |
# | 26 |     40019.0     | 27 | 7/25/2024 16:26 | Matthew.Thompson@sfmta.com | Matthew Thompson | Matthew Thompson |     40019.0     |           Charles J Brenham Pl & Market St NE corner, far-side stop           |       Muni Shared Stop       |                                  None                                  |    In Person    |         nan         |         7/25/2024          |       4:22:00 PM       |           No           |          nan          |                       nan                        |                                  nan                                   |            nan            |                                                   nan                                                   |                            Yes                             |                              No                              |                   Maybe                    |               Unclear if this is the right stop ID (18407 posted)               |                                                                             Maybe                                                                             |                                  No                                  |                       Red painted is almost entirely faded away, no visible stenciling either                        |                                                                                                                                                                                                                                                                                                                                                                                                                                 https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos/IMG_5822_Matthew%20Thompson.jpeg; https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos/IMG_5823_Matthew%20Thompson.jpeg; https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos/IMG_5824_Matthew%20Thompson.jpeg; https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos/IMG_5825_Matthew%20Thompson.jpeg; https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos/IMG_5826_Matthew%20Thompson.jpeg; https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos/IMG_5827_Matthew%20Thompson.jpeg                                                                                                                                                                                                                                                                                                                                                                                                                                 |                                                                                                                      Stop ID # 18047 ?                                                                                                                       |  nan   |        nan         |
# | 11 |       nan       | 12 | 7/23/2024 13:57 | Matthew.Thompson@sfmta.com | Matthew Thompson | Matthew Thompson |       nan       |                          Market & 9th st, SE corner                           |       Muni Shared Stop       |                                  None                                  |    In Person    |         nan         |         7/23/2024          |       1:50:00 PM       |           No           |          nan          |                       nan                        |                                  nan                                   |            nan            |                                                   nan                                                   |                            Yes                             |                              No                              |                    Yes                     |                                       nan                                       |                                                                              Yes                                                                              |                                Maybe                                 |                                  Red paint is getting chipped but it’s very visible                                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos/image_Matthew%20Thompson%201.jpg; https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos/IMG_5718_Matthew%20Thompson.jpeg; https://sfmta365.sharepoint.com/sites/PermitsAdministration/Shared%20Documents/Apps/Microsoft%20Forms/Commuter%20Shuttle%20Stop%C2%A0Evaluation%20Form%20(Version%202)/Photos/IMG_5719_Matthew%20Thompson.jpeg                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |                                                                                                              Seems to be an inactive Muni stop.                                                                                                              |  nan   |        nan         |
# +----+-----------------+----+-----------------+----------------------------+------------------+------------------+-----------------+-------------------------------------------------------------------------------+------------------------------+------------------------------------------------------------------------+-----------------+---------------------+----------------------------+------------------------+------------------------+-----------------------+--------------------------------------------------+------------------------------------------------------------------------+---------------------------+---------------------------------------------------------------------------------------------------------+------------------------------------------------------------+--------------------------------------------------------------+--------------------------------------------+---------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+--------------------+

# %%
row_count_new = len(df)
print(f"Original number of rows: {row_count_original}")
print(f"New number of rows: {row_count_new}")


# Find duplicates based on 'Shuttle_Stop_ID'
duplicate_rows = df[df.duplicated(subset='Shuttle_Stop_ID', keep=False)]
# Out:
# Original number of rows: 93
# New number of rows: 80

# %%
# Save cleaned data in ProcessedData folder
df.to_csv("ProcessedData\CLEANED Commuter Shuttle Evaluation Data Export 2024-08-01.csv", index=False)
print("done!")
# Out:
# done!
